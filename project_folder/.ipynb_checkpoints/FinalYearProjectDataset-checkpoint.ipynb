# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("imdb_top_1000.csv", encoding='latin1')

# %%
df.sample(3)
# Out:
#                      Series_Title  Released_Year Certificate  Runtime  \
# 51                   Modern Times           1936           G   87 min
# 579  M.S. Dhoni: The Untold Story           2016           U  184 min
# 103                Reservoir Dogs           1992           R   99 min
#
#                        Genre  IMDB_Rating  \
# 51     Comedy, Drama, Family          8.5
# 579  Biography, Drama, Sport          7.8
# 103   Crime, Drama, Thriller          8.3
#
#                                               Overview  Meta_score  \
# 51   The Tramp struggles to live in modern industri...          96
# 579  The untold story of Mahendra Singh Dhoni's jou...          78
# 103  When a simple jewelry heist goes horribly wron...          79
#
#               Director                 Star1             Star2  \
# 51     Charles Chaplin       Charles Chaplin  Paulette Goddard
# 579      Neeraj Pandey  Sushant Singh Rajput      Kiara Advani
# 103  Quentin Tarantino         Harvey Keitel          Tim Roth
#
#               Star3          Star4 No_of_Votes      Gross
# 51    Henry Bergman  Tiny Sandford      217881    163,245
# 579     Anupam Kher   Disha Patani       40416  1,782,795
# 103  Michael Madsen     Chris Penn      918562  2,832,029

# %%
df.columns
# Out:
# Index(['Series_Title', 'Released_Year', 'Certificate', 'Runtime', 'Genre',
#        'IMDB_Rating', 'Overview', 'Meta_score', 'Director', 'Star1', 'Star2',
#        'Star3', 'Star4', 'No_of_Votes', 'Gross'],
#       dtype='object')

# %%
df.shape
# Out:
# (1050, 15)

# %%
df.isnull().sum()
# Out:
# Series_Title     0
# Released_Year    0
# Certificate      0
# Runtime          0
# Genre            0
# IMDB_Rating      0
# Overview         0
# Meta_score       0
# Director         0
# Star1            0
# Star2            0
# Star3            0
# Star4            0
# No_of_Votes      0
# Gross            0
# dtype: int64

# %%
min_year = df['Released_Year'].min()
max_year = df['Released_Year'].max()

print(f"Minimum Released Year: {min_year}")
print(f"Maximum Released Year: {max_year}")
# Out:
# Minimum Released Year: 1920
# Maximum Released Year: 2021

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='IMDB_Rating', bins=20, kde=True)
plt.title('Distribution of IMDb Ratings')
plt.xlabel('IMDb Rating')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data=df, x='Certificate', y='IMDB_Rating')
plt.title('IMDb Ratings by Certificate')
plt.xlabel('Certificate')
plt.ylabel('IMDb Rating')
plt.xticks(rotation=45)
plt.show()

# %%
sns.pairplot(df[['IMDB_Rating', 'Meta_score', 'No_of_Votes', 'Gross']])
plt.suptitle('Pairplot of Numeric Variables', y=1.02)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='Certificate', order=df['Certificate'].value_counts().index)
plt.title('Count of Movies by Certificate')
plt.xlabel('Certificate')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
top_directors = df['Director'].value_counts().head(10)
plt.figure(figsize=(12, 6))
sns.barplot(x=top_directors.values, y=top_directors.index, palette='viridis')
plt.title('Top 10 Directors by Number of Movies')
plt.xlabel('Number of Movies')
plt.ylabel('Director')
plt.show()
